# %%
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1=pd.read_excel('my_dataset1.xlsx')

# %%
df1

# %%
X = df1[['x1', 'x2', 'x3','x4']]
print(X)

# %%
y = df1[['label']]
print(y)

# %%
X

# %%
x_var=X.to_numpy()
print(x_var)

# %%
y_var=y.to_numpy()
print(y_var)

# %%
y_var.shape

# %%
x_var.shape

# %%
y_var.ravel()
# Out:
# array([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 80, 80, 80, 80,
#        80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80,
#        80, 80, 80, 80, 80, 80, 80, 80, 80])

# %%
y_var.shape
# Out:
# (60, 1)

# %%
# Create the logistic regression classifier
model1 = linear_model.LogisticRegression(solver='liblinear', C=100)

# %%
# Train the classifier
model1.fit(x_var, y_var.ravel())

# %%
pred_class=model1.predict(np.array([[1,2,3,4]]))
print(pred_class)
