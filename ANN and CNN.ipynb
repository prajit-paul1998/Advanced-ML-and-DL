# %% [markdown]
# A basic neural network that processes the MNIST dataset
#
#
# http://yann.lecun.com/exdb/mnist/
#
# training set of 60,000 examples, and a test set of 10,000 examples

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape

# %%
len(test_labels)

# %%
test_labels

# %%
28*28
# Out:
# 784

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 3ms/step - loss: 0.2664 - accuracy: 0.9240
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1091 - accuracy: 0.9679
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0709 - accuracy: 0.9782
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0521 - accuracy: 0.9847
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0389 - accuracy: 0.9883

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 [==============================] - 0s 69ms/step
# array([2.5445635e-07, 1.8103966e-09, 1.1238823e-05, 5.0228602e-05,
#        1.6778325e-11, 1.6553678e-08, 9.4949274e-12, 9.9992073e-01,
#        1.3120525e-06, 1.6161897e-05], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# 7

# %%
predictions[0][7]
# Out:
# 0.9999207

# %%
test_labels[0]

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0593 - accuracy: 0.9816
# test_acc: 0.9815999865531921

# %% [markdown]
# Instantiating a small convnet
#
# a collection of Conv2D and Maxpooling layers followed by a Dense layer

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))#(shape=(img height,width,channels))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense_2 (Dense)             (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
3*3*128

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 10s 4ms/step - loss: 0.1581 - accuracy: 0.9504
# Epoch 2/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0449 - accuracy: 0.9857
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0311 - accuracy: 0.9903
# Epoch 4/5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0237 - accuracy: 0.9921
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0187 - accuracy: 0.9944

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0236 - accuracy: 0.9921
# Test accuracy: 0.992
