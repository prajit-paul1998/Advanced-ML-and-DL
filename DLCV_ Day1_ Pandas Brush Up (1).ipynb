# %% [markdown]
# #Pandas Brush Up

# %%
# !pip install pandas

# %% [markdown]
# ###Pandas is used for data analysis and visualization

# %%
# %matplotlib inline
import pandas as pd

df = pd.DataFrame({'Marks':[None,55,66,46,34,22,18,55],'Name':['def','pqr','gpi','xyz','abc','ccv','otp','por']})
df.head()
# Out:
#    Marks Name
# 0    NaN  def
# 1   55.0  pqr
# 2   66.0  gpi
# 3   46.0  xyz
# 4   34.0  abc

# %%
df
# Out:
#    Marks Name
# 0    NaN  def
# 1   55.0  pqr
# 2   66.0  gpi
# 3   46.0  xyz
# 4   34.0  abc
# 5   22.0  ccv
# 6   18.0  otp
# 7   55.0  por

# %%
df['Marks']
# Out:
# 0     NaN
# 1    55.0
# 2    66.0
# 3    46.0
# 4    34.0
# 5    22.0
# 6    18.0
# 7    55.0
# Name: Marks, dtype: float64

# %%
df['Marks'].value_counts()
# Out:
# 55.0    2
# 66.0    1
# 46.0    1
# 34.0    1
# 22.0    1
# 18.0    1
# Name: Marks, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# def    1
# pqr    1
# gpi    1
# xyz    1
# abc    1
# ccv    1
# otp    1
# por    1
# Name: Name, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 8

# %%
df['Marks'].nunique()
# Out:
# 6

# %%
ans_arr=df['Name'].unique()

# %%
print(ans_arr)
print(type(ans_arr))
# Out:
# ['def' 'pqr' 'gpi' 'xyz' 'abc' 'ccv' 'otp' 'por']
# <class 'numpy.ndarray'>

# %%
ans_arr.dtype
# Out:
# dtype('O')

# %%
df
# Out:
#    Marks Name
# 0    NaN  def
# 1   55.0  pqr
# 2   66.0  gpi
# 3   46.0  xyz
# 4   34.0  abc
# 5   22.0  ccv
# 6   18.0  otp
# 7   55.0  por

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Marks   7 non-null      float64
#  1   Name    8 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df.describe('')
# Out:
#            Marks
# count   7.000000
# mean   42.285714
# std    18.117342
# min    18.000000
# 50%    46.000000
# max    66.000000

# %%
df
# Out:
#    Marks Name
# 0    NaN  def
# 1   55.0  pqr
# 2   66.0  gpi
# 3   46.0  xyz
# 4   34.0  abc
# 5   22.0  ccv
# 6   18.0  otp
# 7   55.0  por

# %%
# selection of data from dataframe
df_2=df[df['Marks']>50]
print(df_2)
# Out:
#    Marks Name
# 1   55.0  pqr
# 2   66.0  gpi
# 7   55.0  por

# %%
# selection of data from dataframe
df_3=df[df['Marks']<35]
print(df_3)
# Out:
#    Marks Name
# 4   34.0  abc
# 5   22.0  ccv
# 6   18.0  otp

# %%
def pract_marks(data1):
    return data1+15


df_4=df['Marks'].apply(pract_marks)
df_4
# Out:
# 0     NaN
# 1    70.0
# 2    81.0
# 3    61.0
# 4    49.0
# 5    37.0
# 6    33.0
# 7    70.0
# Name: Marks, dtype: float64

# %%
df_3.head()

# %%
df.columns
# Out:
# Index(['Marks', 'Name'], dtype='object')

# %%
df

# %%
df.sort_values(by='Name')
# Out:
#    Marks Name
# 4   34.0  abc
# 5   22.0  ccv
# 0    NaN  def
# 2   66.0  gpi
# 6   18.0  otp
# 7   55.0  por
# 1   55.0  pqr
# 3   46.0  xyz

# %%
df.isnull()
# Out:
#    Marks   Name
# 0   True  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False
# 6  False  False
# 7  False  False

# %%
'e1 e2 e3 e4'.split()
# Out:
# ['e1', 'e2', 'e3', 'e4']

# %%
from numpy.random import randn
df = pd.DataFrame(randn(4,4),index='e1 e2 e3 e4'.split(),columns='f1 f2 f3 f4'.split())
df
# Out:
#           f1        f2        f3        f4
# e1  1.255180  0.130629 -0.505626 -0.209620
# e2  0.564878  2.148516  0.615526  1.195005
# e3 -1.149353 -1.495146  0.880306 -1.632263
# e4 -0.631348 -0.574397 -0.571173  0.173535

# %%
df[['f3','f4']]
# Out:
#           f3        f4
# e1 -0.505626 -0.209620
# e2  0.615526  1.195005
# e3  0.880306 -1.632263
# e4 -0.571173  0.173535

# %%
df['f5'] = df['f3'] + df['f2']
df
# Out:
#           f1        f2        f3        f4        f5
# e1  1.255180  0.130629 -0.505626 -0.209620 -0.374997
# e2  0.564878  2.148516  0.615526  1.195005  2.764042
# e3 -1.149353 -1.495146  0.880306 -1.632263 -0.614839
# e4 -0.631348 -0.574397 -0.571173  0.173535 -1.145571

# %%
df
# Out:
#           f1        f2        f3        f4        f5
# e1  1.255180  0.130629 -0.505626 -0.209620 -0.374997
# e2  0.564878  2.148516  0.615526  1.195005  2.764042
# e3 -1.149353 -1.495146  0.880306 -1.632263 -0.614839
# e4 -0.631348 -0.574397 -0.571173  0.173535 -1.145571

# %%
df.loc['e2']  # Retrieval of data from rows
# Out:
# f1    0.564878
# f2    2.148516
# f3    0.615526
# f4    1.195005
# f5    2.764042
# Name: e2, dtype: float64

# %%
df>0
# Out:
#        f1     f2     f3     f4     f5
# e1   True   True  False  False  False
# e2   True   True   True   True   True
# e3  False  False   True  False  False
# e4  False  False  False   True  False

# %%
df['f1'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')  #  A style from R language
df['f1'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df['f1'].hist()
# Out:
# <Axes: >

# %%
print(df['f1'])

plt.style.use('ggplot')
df.plot.line(y='f1',figsize=(5,5))
# Out:
# e1    1.255180
# e2    0.564878
# e3   -1.149353
# e4   -0.631348
# Name: f1, dtype: float64
# <Axes: >

# %%
print(df['f1'])
print(df['f2'])
df.plot.scatter(x='f1',y='f2')
# Out:
# e1    1.255180
# e2    0.564878
# e3   -1.149353
# e4   -0.631348
# Name: f1, dtype: float64
# e1    0.130629
# e2    2.148516
# e3   -1.495146
# e4   -0.574397
# Name: f2, dtype: float64
# <Axes: xlabel='f1', ylabel='f2'>
